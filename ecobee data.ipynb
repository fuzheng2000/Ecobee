# %%
import os
filePath = "F:/Ecobee/files/2015"
for i,j,k in os.walk(filePath):
    print(k)
# Out:
# ['0005eeb24efd9dae77de154e78c463a4256d88dd.csv.zip', '000d8f2faae9cb42cb4266cfc63bca977e229136.csv.zip', '000ddb27938655fa6573daa6b3b2e3b99229957b.csv.zip', '000ea956cb420704316645e797335329c64fb1f3.csv.zip', '0010ad62d77f975c78fd48e5804ca33946addff4.csv.zip', '001b5ab7b1a10b141bab3f5aa9d3dba4770ae3fc.csv.zip', '0027739e387d6725f8ffc44d847b924dc6443e5e.csv.zip', '0031fe0263b18f5fd70c0e47892a5ad0daf5db2e.csv.zip', '0044f3b6d417a0803b0a90b6f64637113ac00195.csv.zip', '00451445795c8af7458fc41432e9898b4382710b.csv.zip', '0059aeeab05b3f659740a27aa28e9cacb5526183.csv.zip', '005e071757e45285888c5db640f72812973ae0ee.csv.zip', '00648654f526da812950a4601ecea4cafba5d1f2.csv.zip', '0064e9599541de5fd5cf8ea03bac42738c537453.csv.zip', '006dec40c94be0808c53821a0fe1e1b803a340cc.csv.zip', '006fd1024f0648bc4571dd2cd81a51ab7c8f89cd.csv.zip', '008726c56534e602160613e9c479e6395e7a06f5.csv.zip', '00940f20656cce537f99594c7632fafe77edce06.csv.zip', '00b04ee853ae09b37418e409c105614f1d914b17.csv.zip', '00bc9935
# ...

# %%
from zipfile import ZipFile
import pandas as pd
myzip=ZipFile('F:/Ecobee/files/2015/0005eeb24efd9dae77de154e78c463a4256d88dd.csv.zip')
f=myzip.open('0005eeb24efd9dae77de154e78c463a4256d88dd.csv')
df=pd.read_csv(f)
print(df.tail())
f.close()
myzip.close()
# Out:
#                   DateTime HvacMode Event Schedule  T_ctrl  T_stp_cool  \
# 32311  2015-12-31 23:35:00     heat  Hold    Sleep    68.0        71.0
# 32312  2015-12-31 23:40:00     heat  Hold    Sleep    68.0        71.0
# 32313  2015-12-31 23:45:00     heat  Hold    Sleep    69.0        71.0
# 32314  2015-12-31 23:50:00     heat  Hold    Sleep    70.0        71.0
# 32315  2015-12-31 23:55:00     heat  Hold    Sleep    70.0        71.0
#
#        T_stp_heat  Humidity  HumidityExpectedLow  HumidityExpectedHigh  ...  \
# 32311        71.0      43.0                  0.0                   0.0  ...
# 32312        71.0      43.0                  0.0                   0.0  ...
# 32313        71.0      42.0                  0.0                   0.0  ...
# 32314        71.0      42.0                  0.0                   0.0  ...
# 32315        71.0      43.0                  0.0                   0.0  ...
#
#        Remote_Sensor_7_Temperature  Remote_Sensor_7_Motion  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32316 entries, 0 to 32315
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DateTime                      32316 non-null  object
#  1   HvacMode                      31811 non-null  object
#  2   Event                         10217 non-null  object
#  3   Schedule                      31811 non-null  object
#  4   T_ctrl                        31811 non-null  float64
#  5   T_stp_cool                    31811 non-null  float64
#  6   T_stp_heat                    31811 non-null  float64
#  7   Humidity                      31811 non-null  float64
#  8   HumidityExpectedLow           31811 non-null  float64
#  9   HumidityExpectedHigh          31811 non-null  float64
#  10  auxHeat1                      31811 non-null  float64
#  11  auxHeat2                      31811 non-null  float64
# ...

# %%
pd.options.display.max_columns = df.shape[1]
df.describe(include = 'all')
# Out:
#                    DateTime HvacMode       Event Schedule        T_ctrl  \
# count                 32316    31811       10217    31811  31811.000000
# unique                32304        2           4        3           NaN
# top     2015-10-31 21:15:00     auto  Smart Away     Home           NaN
# freq                      2    20829        5640    18815           NaN
# mean                    NaN      NaN         NaN      NaN     69.084468
# std                     NaN      NaN         NaN      NaN      1.566989
# min                     NaN      NaN         NaN      NaN     62.000000
# 25%                     NaN      NaN         NaN      NaN     68.000000
# 50%                     NaN      NaN         NaN      NaN     69.000000
# 75%                     NaN      NaN         NaN      NaN     70.000000
# max                     NaN      NaN         NaN      NaN     75.000000
#
#           T_stp_cool    T_stp_heat      Humidity  HumidityExpectedLow  \
# ...

# %%
print(df.isnull().sum())
# Out:
# DateTime                            0
# HvacMode                          505
# Event                           22099
# Schedule                          505
# T_ctrl                            505
# T_stp_cool                        505
# T_stp_heat                        505
# Humidity                          505
# HumidityExpectedLow               505
# HumidityExpectedHigh              505
# auxHeat1                          505
# auxHeat2                          505
# auxHeat3                          505
# compCool1                         505
# compCool2                         505
# compHeat1                         505
# compHeat2                         505
# fan                               505
# Thermostat_Temperature            502
# Thermostat_Motion                 502
# Remote_Sensor_1_Temperature       510
# Remote_Sensor_1_Motion            509
# Remote_Sensor_2_Temperature     32316
# Remote_Sensor_2_Motion          32316
# Remote_Sensor_3_Temperature     32316
# ...
