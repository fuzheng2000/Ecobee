# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os


import graphviz
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline

# %%
# %load_ext blackcellmagic

# %%
#2018
from zipfile import ZipFile
directory_18 = r'F:\Ecobee\files\2018_sac'
df_sac_18_daily_offpeak = pd.DataFrame()
import datetime
for filename in os.listdir(directory_18):
    myzip = ZipFile(os.path.join(directory_18, filename))
    g = myzip.open(filename[:-4])
    df_temp = pd.read_csv(g, parse_dates=['DateTime'])
    df_temp1 = df_temp[df_temp.HvacMode=='cool']
    df_temp1['Date'] = df_temp1['DateTime'].dt.date
    df_temp1['user_id'] = filename[:-8]
    df_temp1 = df_temp1[(df_temp1['DateTime'].dt.hour >= 0) &
                        (df_temp1['DateTime'].dt.hour < 12) &
                        (df_temp1['DateTime'].dt.month >= 6) &
                        (df_temp1['DateTime'].dt.month <=
                         9)]  #summer days only
    df_day = (
        df_temp1.groupby([df_temp1['Date']])
        .agg(
            avg_set_point_cool=pd.NamedAgg(column="T_stp_cool", aggfunc=np.mean),
            user_id=pd.NamedAgg(column="user_id", aggfunc=min),
        )
        .reset_index()
    )
    df_sac_18_daily_offpeak = pd.concat([df_sac_18_daily_offpeak, df_day])
    g.close()
    myzip.close()

# %%
df_sac_18_daily_offpeak.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10974 entries, 0 to 14
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                10974 non-null  object
#  1   avg_set_point_cool  10901 non-null  float64
#  2   user_id             10974 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 342.9+ KB

# %%
from zipfile import ZipFile
df_sac_19_daily_offpeak = pd.DataFrame()
directory_19 = r'F:\Ecobee\files\2019_sac'
import datetime
for filename in os.listdir(directory_19):
    myzip = ZipFile(os.path.join(directory_19, filename))
    f = myzip.open(filename[:-4])
    df_temp = pd.read_csv(f, parse_dates=['DateTime'])
    df_temp1 = df_temp[df_temp.HvacMode=='cool']
    df_temp1['Date'] = df_temp1['DateTime'].dt.date
    df_temp1['user_id'] = filename[:-8]
    df_temp1 = df_temp1[(df_temp1['DateTime'].dt.hour >= 0) &
                        (df_temp1['DateTime'].dt.hour < 12) &
                        (df_temp1['DateTime'].dt.month >= 6) &
                        (df_temp1['DateTime'].dt.month <=
                         9)]  #summer days only
    df_day = (
        df_temp1.groupby(["Date"])
        .agg(
            avg_set_point_cool=pd.NamedAgg(column="T_stp_cool", aggfunc=np.mean),
            user_id=pd.NamedAgg(column="user_id", aggfunc=min),
        )
        .reset_index()
    )
    df_sac_19_daily_offpeak = pd.concat([df_sac_19_daily_offpeak, df_day])
    f.close()
    myzip.close()

# %%
df_sac_19_daily_offpeak.head()
#note there is a "time jump" from 2019-07-25 16:55 to 2019-07-26 17:00
# Out:
#          Date  avg_set_point_cool                                   user_id
# 0  2019-06-03                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 1  2019-06-04                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 2  2019-06-05                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 3  2019-06-06                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 4  2019-06-07                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516

# %%
df_sac_18n19_daily_offpeak=pd.concat([df_sac_18_daily_offpeak,df_sac_19_daily_offpeak])
df_sac_18n19_daily_offpeak.head()
# Out:
#          Date  avg_set_point_cool                                   user_id
# 0  2018-06-02                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 1  2018-06-03                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 2  2018-06-04                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 3  2018-06-05                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 4  2018-06-06                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516

# %%
df_sac_18n19_daily_offpeak['count'] = df_sac_18n19_daily_offpeak.groupby('user_id')['user_id'].transform('count')
df_sac_18n19_daily_offpeak['count'].value_counts().reset_index().sort_values('index',ascending=False).head(30)
# Out:
#     index  count
# 0     242   3872
# 4     241    964
# 31    240    240
# 5     239    956
# 8     238    714
# 6     237    948
# 32    236    236
# 10    234    468
# 33    232    232
# 34    230    230
# 36    228    228
# 38    227    227
# 11    226    452
# 39    225    225
# 12    223    446
# 40    222    222
# 42    219    219
# 13    218    436
# 7     216    864
# 44    213    213
# 46    211    211
# 47    210    210
# 48    209    209
# 49    208    208
# 50    206    206
# 51    203    203
# 52    202    202
# 16    201    402
# 55    195    195
# 56    194    194

# %%
df_sac_18n19_daily_offpeak.head()
# Out:
#          Date  avg_set_point_cool                                   user_id  \
# 0  2018-06-01           74.500000  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 1  2018-06-02           77.000000  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 2  2018-06-03           77.555556  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 3  2018-06-04           78.000000  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 4  2018-06-06           77.000000  00e2f68ec737f7480114a67bbef7c5f65b6b8516
#
#    count
# 0    236
# 1    236
# 2    236
# 3    236
# 4    236

# %%
df_sac_18n19_daily_offpeak=df_sac_18n19_daily_offpeak[df_sac_18n19_daily_offpeak['count']>=220]
df_sac_18n19_daily_offpeak['Date']=pd.to_datetime(df_sac_18n19_daily_offpeak['Date'])
df_sac_18n19_daily_offpeak.head()
# Out:
#         Date  avg_set_point_cool                                   user_id  \
# 0 2018-06-02                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 1 2018-06-03                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 2 2018-06-04                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 3 2018-06-05                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 4 2018-06-06                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
#
#    count
# 0    239
# 1    239
# 2    239
# 3    239
# 4    239

# %%
df_temperature=pd.read_csv(r'F:\Ecobee\smf_temp_18and19.csv', parse_dates=['DATE'])
df_temperature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  730 non-null    object
#  1   NAME     730 non-null    object
#  2   DATE     730 non-null    datetime64[ns]
#  3   TAVG     730 non-null    int64
#  4   TMAX     730 non-null    int64
#  5   TMIN     730 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 34.3+ KB

# %%
df_temperature.head()
# Out:
#        STATION                            NAME       DATE  TAVG  TMAX  TMIN
# 0  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-01-01    49    65    38
# 1  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-01-02    48    59    39
# 2  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-01-03    50    57    40
# 3  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-01-04    55    65    49
# 4  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-01-05    55    60    50

# %%
df_sac_18n19_daily_offpeak_w_temperature=pd.merge(df_sac_18n19_daily_offpeak,df_temperature,how='left', left_on='Date', right_on='DATE')
df_sac_18n19_daily_offpeak_w_temperature.head()
# Out:
#         Date  avg_set_point_cool                                   user_id  \
# 0 2018-06-02                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 1 2018-06-03                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 2 2018-06-04                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 3 2018-06-05                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 4 2018-06-06                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
#
#    count      STATION                            NAME       DATE  TAVG  TMAX  \
# 0    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-02    74    96
# 1    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-03    78    98
# 2    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-04    76    89
# 3    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-05    67    84
# 4    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-06    65    79
#
#    TMIN
# 0    55
# 1    58
# 2    58
# 3    53
# 4    54

# %%
df_sac_18n19_daily_offpeak_w_temperature[
    'TAVG_less_62'] = df_sac_18n19_daily_offpeak_w_temperature['TAVG'] - 62
df_sac_18n19_daily_offpeak_w_temperature['TAVG_less_62'] = df_sac_18n19_daily_offpeak_w_temperature['TAVG_less_62'].apply(lambda x : x if x > 0 else 0)

# %%
df_sac_18n19_daily_offpeak_w_temperature['y2019']=np.where(df_sac_18n19_daily_offpeak_w_temperature['Date'].dt.year== 2019, 1, 0)
# [df_sac_18n19_daily_offpeak_w_temperature['Date'].dt.year==2019]
df_sac_18n19_daily_offpeak_w_temperature.describe()
# Out:
#        avg_set_point_cool         count          TAVG          TMAX  \
# count        10567.000000  10660.000000  10660.000000  10660.000000
# mean            77.495617    237.054784     72.770826     90.445216
# std              4.191829      6.171958      5.183463      7.222770
# min             67.000000    222.000000     58.000000     69.000000
# 25%             74.514881    234.000000     69.000000     86.000000
# 50%             78.000000    239.000000     73.000000     91.000000
# 75%             80.000000    242.000000     76.000000     96.000000
# max             92.000000    242.000000     86.000000    105.000000
#
#                TMIN  TAVG_less_62         y2019
# count  10660.000000  10660.000000  10660.000000
# mean      58.539118     10.806567      0.503189
# std        3.997756      5.095754      0.500013
# min       45.000000      0.000000      0.000000
# 25%       56.000000      7.000000      0.000000
# 50%       58.000000     11.000000      1.000000
# 75%       61.000000     14.000000      1.000000
# max       69.000000     24.000000      1.000000

# %%
df_sac_18n19_daily_offpeak_w_temperature[
    'interaction'] = df_sac_18n19_daily_offpeak_w_temperature[
        'TAVG_less_62'] * df_sac_18n19_daily_offpeak_w_temperature['y2019']

# %%
import statsmodels.api as sm


def regress(data, yvar, xvars):
    Y = data[yvar]
    X = data[xvars]
    X['intercept'] = 1.
    result = sm.OLS(Y, X).fit(cov_type='HC1')
    return result.params


#This is what you need
results=df_sac_18n19_daily_offpeak_w_temperature.groupby('user_id').apply(
    regress, 'avg_set_point_cool', ['TAVG_less_62','interaction']).reset_index()
results.head(10)
# Out:
#                                     user_id  TAVG_less_62  interaction  \
# 0  00e2f68ec737f7480114a67bbef7c5f65b6b8516     -0.011288     0.054616
# 1  0614c5d47de23d61b21be2141907668a54bf45a0      0.106409    -0.455019
# 2  0773f65bc76833bddd55f0f850ded5d14bc8ab99           NaN          NaN
# 3  084a2b8c0522a36209d062d852d04bb64494ea84           NaN          NaN
# 4  0ed748d62777165f02e04693fa57812603a16fa7     -0.087373     0.112439
# 5  0f50223ca3a7c1def87d95d3696719692d5d3d33     -0.048432     0.089434
# 6  138d3e21dc03b5b4bd5d3063859d11ad3bbac2fb     -0.293688     0.113853
# 7  1498973dc91f1608b32e7cd1ff11ea8e4b5d94b5           NaN          NaN
# 8  186741f3ed099caff39bf2194448a8c9d661872d     -0.036479    -0.007370
# 9  1a85f6383418f7b3351f3ea3356f6fdc0875db6f           NaN          NaN
#
#    intercept
# 0  76.995676
# 1  75.940391
# 2        NaN
# 3        NaN
# 4  70.594585
# 5  79.462648
# 6  78.705221
# 7        NaN
# 8  77.252744
# 9        NaN

# %%
# creat temperature bins
df_sac_18n19_daily_offpeak_w_temperature["temp_bins"] = pd.cut(
    df_sac_18n19_daily_offpeak_w_temperature["TAVG"],
    bins=[57, 62, 66, 70, 74, 78, 82, 86],
    right=True,
)
df_sac_18n19_daily_offpeak_w_temperature["coded_bins"] = pd.cut(
    df_sac_18n19_daily_offpeak_w_temperature["TAVG"],
    bins=[57, 62, 66, 70, 74, 78, 82, 86],
    right=True,
    labels=['1', '2', '3', '4', '5', '6', '7']
)

# %%
df_sac_18n19_daily_offpeak_w_temperature.head()
# Out:
#         Date  avg_set_point_cool                                   user_id  \
# 0 2018-06-02                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 1 2018-06-03                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 2 2018-06-04                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 3 2018-06-05                78.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
# 4 2018-06-06                77.0  00e2f68ec737f7480114a67bbef7c5f65b6b8516
#
#    count      STATION                            NAME       DATE  TAVG  TMAX  \
# 0    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-02    74    96
# 1    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-03    78    98
# 2    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-04    76    89
# 3    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-05    67    84
# 4    239  USW00023232  SACRAMENTO AIRPORT ASOS, CA US 2018-06-06    65    79
#
#    TMIN  TAVG_less_62  y2019  interaction temp_bins coded_bins
# 0    55            12      0            0  (70, 74]          4
# 1    58            16      0            0  (74, 78]          5
# 2    58            14      0            0  (74, 78]          5
# 3    53             5      0            0  (66, 70]          3
# 4    54             3      0            0  (62, 66]          2

# %%
list_of_temp_bins=df_sac_18n19_daily_offpeak_w_temperature["temp_bins"].unique()
# list_of_temp_bins=list_of_temp_bins.tolist()
# list_of_temp_bins.sort()
list_of_temp_bins
# Out:
# [(70, 74], (74, 78], (66, 70], (62, 66], (57, 62], (82, 86], (78, 82]]
# Categories (7, interval[int64]): [(57, 62] < (62, 66] < (66, 70] < (70, 74] < (74, 78] < (78, 82] < (82, 86]]

# %%
list_of_coded_bins=df_sac_18n19_daily_offpeak_w_temperature["coded_bins"].unique()
print(type(list_of_coded_bins))
list_of_coded_bins
# Out:
# <class 'pandas.core.arrays.categorical.Categorical'>
# ['4', '5', '3', '2', '1', '7', '6']
# Categories (7, object): ['1' < '2' < '3' < '4' < '5' < '6' < '7']

# %%
list_of_coded_bins=list_of_coded_bins.tolist()
list_of_coded_bins.sort()
list_of_coded_bins
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
df_sac_18n19_daily_offpeak_w_temperature["const"] = 1
list_of_results=[]
for coded_bin in list_of_coded_bins:
    reg_data = df_sac_18n19_daily_offpeak_w_temperature[
        df_sac_18n19_daily_offpeak_w_temperature["coded_bins"] == coded_bin]
    current_reg=sm.OLS(endog=reg_data['avg_set_point_cool'], \
              exog=reg_data[['TAVG_less_62','interaction','const']], \
                missing='drop')
    current_regresult =  current_reg.fit()#fit(cov_type='HC1')
    print('Results for Bin '+str(coded_bin)*20)
    print('\n')
    print(current_regresult.summary())
    print('\n')
    print('\n')
    list_of_results.append(current_regresult)
# Out:
# Results for Bin 11111111111111111111
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):                nan
# Time:                        20:47:32   Log-Likelihood:                -502.93
# No. Observations:                 172   AIC:                             1008.
# Df Residuals:                     171   BIC:                             1011.
# Df Model:                           0
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62          0          0        nan        nan           0           0
# interaction           0          0        nan        nan           0           0
# const           77.5468      0.344    225.120      0.000      76.867      78.227
# ==============================================================================
# Omnibus:                       28.109   Durbin-Watson:                   1.173
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.733
# Skew:                           0.848   Prob(JB):                     1.17e-10
# Kurtosis:                       4.872   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
#
#
# Results for Bin 22222222222222222222
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.2345
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):              0.791
# Time:                        20:47:32   Log-Likelihood:                -2693.5
# No. Observations:                 950   AIC:                             5393.
# Df Residuals:                     947   BIC:                             5408.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62    -0.1113      0.163     -0.685      0.494      -0.430       0.208
# interaction      0.0177      0.093      0.189      0.850      -0.166       0.201
# const           78.1707      0.490    159.472      0.000      77.209      79.133
# ==============================================================================
# Omnibus:                       17.311   Durbin-Watson:                   0.448
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.913
# Skew:                           0.178   Prob(JB):                     3.89e-06
# Kurtosis:                       3.709   Cond. No.                         13.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# Results for Bin 33333333333333333333
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.09746
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):              0.907
# Time:                        20:47:32   Log-Likelihood:                -7095.2
# No. Observations:                2481   AIC:                         1.420e+04
# Df Residuals:                    2478   BIC:                         1.421e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62    -0.0355      0.089     -0.399      0.690      -0.210       0.139
# interaction      0.0004      0.028      0.014      0.989      -0.054       0.055
# const           77.8857      0.539    144.531      0.000      76.829      78.942
# ==============================================================================
# Omnibus:                      130.368   Durbin-Watson:                   0.270
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              217.065
# Skew:                           0.423   Prob(JB):                     7.33e-48
# Kurtosis:                       4.177   Cond. No.                         48.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# Results for Bin 44444444444444444444
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.538
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):             0.0792
# Time:                        20:47:32   Log-Likelihood:                -8865.3
# No. Observations:                3110   AIC:                         1.774e+04
# Df Residuals:                    3107   BIC:                         1.775e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62    -0.1444      0.065     -2.232      0.026      -0.271      -0.018
# interaction   4.438e-06      0.014      0.000      1.000      -0.028       0.028
# const           79.0944      0.679    116.419      0.000      77.762      80.426
# ==============================================================================
# Omnibus:                      160.240   Durbin-Watson:                   0.301
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              265.708
# Skew:                           0.420   Prob(JB):                     2.01e-58
# Kurtosis:                       4.160   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# Results for Bin 55555555555555555555
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4886
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):              0.614
# Time:                        20:47:32   Log-Likelihood:                -6952.7
# No. Observations:                2447   AIC:                         1.391e+04
# Df Residuals:                    2444   BIC:                         1.393e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62    -0.0567      0.079     -0.719      0.472      -0.211       0.098
# interaction     -0.0078      0.011     -0.682      0.495      -0.030       0.015
# const           78.1612      1.166     67.028      0.000      75.874      80.448
# ==============================================================================
# Omnibus:                      148.964   Durbin-Watson:                   0.330
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              248.397
# Skew:                           0.475   Prob(JB):                     1.15e-54
# Kurtosis:                       4.239   Cond. No.                         239.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# Results for Bin 66666666666666666666
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.6882
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):              0.503
# Time:                        20:47:32   Log-Likelihood:                -3247.5
# No. Observations:                1142   AIC:                             6501.
# Df Residuals:                    1139   BIC:                             6516.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62    -0.1478      0.126     -1.172      0.241      -0.395       0.100
# interaction      0.0042      0.014      0.299      0.765      -0.023       0.032
# const           79.8671      2.246     35.559      0.000      75.460      84.274
# ==============================================================================
# Omnibus:                       88.017   Durbin-Watson:                   0.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              153.469
# Skew:                           0.543   Prob(JB):                     4.73e-34
# Kurtosis:                       4.431   Cond. No.                         392.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
#
# Results for Bin 77777777777777777777
#
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     avg_set_point_cool   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                   0.02667
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):              0.974
# Time:                        20:47:32   Log-Likelihood:                -760.37
# No. Observations:                 265   AIC:                             1527.
# Df Residuals:                     262   BIC:                             1537.
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# TAVG_less_62    -0.0561      0.408     -0.138      0.891      -0.859       0.747
# interaction      0.0089      0.038      0.231      0.818      -0.067       0.085
# const           78.0200      8.948      8.719      0.000      60.401      95.639
# ==============================================================================
# Omnibus:                       20.671   Durbin-Watson:                   0.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.351
# Skew:                           0.518   Prob(JB):                     2.57e-07
# Kurtosis:                       4.295   Cond. No.                     1.04e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
interaction_coeffs = []
for i in range(7):
    interaction_coeffs.append(list_of_results[i].params[1])
print(interaction_coeffs)
interaction_coeff_se = []
for i in range(7):
    interaction_coeff_se.append(list_of_results[i].bse[1])
print(interaction_coeff_se)
interaction_coeffs_plusSE = [
    a + b for a, b in zip(interaction_coeffs, interaction_coeff_se)
]
print(interaction_coeffs_plusSE)
interaction_coeffs_minusSE = [
    a - b for a, b in zip(interaction_coeffs, interaction_coeff_se)
]
print(interaction_coeffs_minusSE)

# %%
# x axis range
x = range(len(interaction_coeffs))
plt.figure(figsize=(15,10))
# y
plt.plot(x,interaction_coeffs,'o-', label='interaction coeff')
plt.plot(x,[0] * len(interaction_coeffs))
plt.plot(x,interaction_coeffs_plusSE,'o-', label='upper bound')
plt.plot(x,interaction_coeffs_minusSE,'o-', label='lower bound')
plt.legend(loc="upper left")
plt.xticks(x,('(57, 62]', '(62, 66]', '(66, 70]', '(70, 74]', '(74, 78]', '(78, 82]',  '(82, 86]') )
plt.grid()
plt.title("Y= avg_set_point_cool (offpeak)")
plt.show()

# %% [markdown]
# no significant impact on set_point when off-peak
